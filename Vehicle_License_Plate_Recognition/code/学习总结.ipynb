# %% [markdown]
# # 柱状图

# %% [markdown]
# # 饼状图

# %%
#饼状图还是放在本地跑吧，可以放大

# %% [markdown]
# 在自己的数据上，训练集与测试集分别为 95%  5%<br>
# 用了三层卷积池化，卷积核个数分别为 48 96 144 <br>
# 激活函数用的prelu α用的0.9<br>
# 召回率只有鲁最低 15% 之后将鲁的标签惩罚为0.97  鲁提高为84%  但总体准确率变低<br>
